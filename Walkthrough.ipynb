# %% [markdown]
# # Time Series Workshop &minus; Walkthrough
#
# ODSC West &minus; November 2, 2017
#
# Michael Schmidt
#
# https://github.com/mds47/time-series-workshop

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.base import BaseEstimator, RegressorMixin

# %% [markdown]
# ## Example Time Series Data Set

# %%
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
plt.figure(figsize=(9,3))
plt.plot(data.date, data.y, '.-', c='gray')

t_diff_median = data.date.diff().median()
print('Average time step: {!s}'.format(t_diff_median))
# Out:
# Average time step: 31 days 00:00:00

# %%
a = pd.DataFrame(([1,2,3]))
#a.shift(0)
print(a)
print(a.shift(1))
print(a.shift(2))
print(a.shift(3))
# Out:
#    0
# 0  1
# 1  2
# 2  3
#      0
# 0  NaN
# 1  1.0
# 2  2.0
#      0
# 0  NaN
# 1  NaN
# 2  1.0
#     0
# 0 NaN
# 1 NaN
# 2 NaN

# %% [markdown]
# ## Fitting a Model

# %%
def fit_model(t, X, y, distance, test_size=0.2, log_transform=False, estimator=None, plot=False):
    
    # apply forecast distance
    X = X.shift(distance)
    
    # ignore missing value rows
    non_null = X.dropna(how='any').index.values

    # create holdout set
    if isinstance(test_size, float):
        test_size = int(test_size * len(t))
    train = non_null[:-test_size]
    test  = non_null[-test_size:]

    # standardize
    numeric_cols = X.select_dtypes(include=[np.number]).columns
    centers = X.loc[train, numeric_cols].mean(axis=0)
    #print(X.head(13),y.head(13))
    scales = np.maximum(1e-15, X.loc[train, numeric_cols].std(axis=0))
    X[numeric_cols] = (X[numeric_cols] - centers)/scales
    
    # fit model
    if estimator is None:
        estimator = ElasticNetCV(n_alphas=100, l1_ratio=0.9, cv=5, random_state=123)
    if log_transform:
        estimator = MultiplicativeEstimator(estimator)
    #print(X.loc[train, :].head())
    estimator.fit(X.loc[train, :], y[train])
    test_score = estimator.score(X.loc[test, :], y[test])

    # plot the fit
    if plot:
        plt.figure(figsize=(9,3))
        plt.plot(t, y, '.', c='gray', alpha=0.7)
        plt.plot(t[train], estimator.predict(X.loc[train, :]), 'b-', lw=2, alpha=0.7)
        plt.plot(t[test], estimator.predict(X.loc[test, :]),  'r-', lw=2, alpha=0.7)
        plt.annotate('Test Score: {}'.format(test_score), 
                     xy=(0, 1), xytext=(12, -12), va='top', 
                     xycoords='axes fraction', textcoords='offset points')
        plt.show()
    return estimator, test_score


def feature_importance_summary(model):
    if hasattr(model, 'coef_'):
        coef = pd.Series(model.coef_, index=X.columns, name='Importance')
        importances = coef.abs()
        importances.sort_values(ascending=False, inplace=True)
        importances = importances[importances > 1e-15]
        display(importances.to_frame().style.bar())
    else:
        raise NotImplemented('Only linear models supported at the momemnt.')
        

class MultiplicativeEstimator(BaseEstimator, RegressorMixin):
    
    def __init__(self, estimator):
        self.estimator = estimator
        
    def fit(self, X, y, *args, **kwargs):
        self.estimator.fit(X, np.log(y), *args, **kwargs)
        return self
    
    def predict(self, X):
        return np.exp(self.estimator.predict(X))
    
    def __getattr__(self, name):
        return getattr(self.estimator, name)

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']

# create features in new dataframe
X = pd.DataFrame()
X['lag 0'] = y.shift(0)
X['lag 1'] = y.shift(1)
X['lag 2'] = y.shift(2)
X['lag 3'] = y.shift(3)
X['lag 4'] = y.shift(4)
X['lag 5'] = y.shift(5)
X['lag 6'] = y.shift(6)
X['lag 7'] = y.shift(7)
X['lag 8'] = y.shift(8)
X['lag 9'] = y.shift(9)
X['lag 10'] = y.shift(10)
X['lag 11'] = y.shift(11)
X['lag 12'] = y.shift(12)

# fit
model, score = fit_model(t, X, y, plot=True, distance=12)

# display importances
feature_importance_summary(model)
# Out:
#     lag 0  lag 1  lag 2  lag 3  lag 4  lag 5  lag 6  lag 7  lag 8  lag 9  \
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     lag 10  lag 11  lag 12
# 0      NaN     NaN     NaN
# 1      NaN     NaN     NaN
# 2      NaN     NaN     NaN
# 3      NaN     NaN     NaN
# 4      NaN     NaN     NaN
# 5      NaN     NaN     NaN
# 6      NaN     NaN     NaN
# 7      NaN     NaN     NaN
# 8      NaN     NaN     NaN
# 9      NaN     NaN     NaN
# 10     NaN     NaN     NaN
# 11     NaN     NaN     NaN
# 12     NaN     NaN     NaN   0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3     lag 4     lag 5     lag 6  \
# 24 -1.552292 -1.518227 -1.706675 -1.498677 -1.243483 -1.057963 -1.040065
# 25 -1.415034 -1.556955 -1.519547 -1.704179 -1.478335 -1.225369 -1.040065
# 26 -1.227864 -1.414954 -1.559646 -1.512377 -1.685557 -1.462528 -1.209696
# 27 -1.302732 -1.221317 -1.412616 -1.553477 -1.492149 -1.671785 -1.450007
# 28 -1.427512 -1.298772 -1.212122 -1.402776 -1.533594 -1.476478 -1.662046
#
#        lag 7     lag 8     lag 9    lag 10    lag 11    lag 12
# 24 -1.197160 -1.364675 -1.224950 -1.156505 -1.324016 -1.387910
# 25 -1.013572 -1.167025 -1.337928 -1.198699 -1.127209 -1.302539
# 26 -1.013572 -0.983493 -1.140216 -1.311216 -1.169382 -1.103338
# 27 -1.183038 -0.983493 -0.956627 -1.114312 -1.281843 -1.146024
# 28 -1.423114 -1.152907 -0.956627 -0.931472 -1.085036 -1.259853
# <style  type="text/css" >
#     #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.6%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.2%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.6%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.3%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.8%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 0%);
#         }    #T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow8_col0 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Importance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row0" class="row_heading level0 row0" >lag 0</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow0_col0" class="data row0 col0" >37.5104</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row1" class="row_heading level0 row1" >lag 12</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow1_col0" class="data row1 col0" >26.9771</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row2" class="row_heading level0 row2" >lag 1</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow2_col0" class="data row2 col0" >14.2074</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row3" class="row_heading level0 row3" >lag 11</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow3_col0" class="data row3 col0" >9.16934</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row4" class="row_heading level0 row4" >lag 8</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow4_col0" class="data row4 col0" >4.59176</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row5" class="row_heading level0 row5" >lag 9</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow5_col0" class="data row5 col0" >1.61383</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row6" class="row_heading level0 row6" >lag 7</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow6_col0" class="data row6 col0" >1.42962</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row7" class="row_heading level0 row7" >lag 2</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow7_col0" class="data row7 col0" >0.958577</td>
#     </tr>    <tr>
#         <th id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8flevel0_row8" class="row_heading level0 row8" >lag 3</th>
#         <td id="T_1148c7cc_de30_11e8_b08b_acbc32b0ef8frow8_col0" class="data row8 col0" >0.40394</td>
#     </tr></tbody>
# </table>

# %%
X.head()
# Out:
#    lag 0  lag 1  lag 2  lag 3  lag 4  lag 5  lag 6  lag 7  lag 8  lag 9  \
# 0    112    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    118  112.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    132  118.0  112.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    129  132.0  118.0  112.0    NaN    NaN    NaN    NaN    NaN    NaN
# 4    121  129.0  132.0  118.0  112.0    NaN    NaN    NaN    NaN    NaN
#
#    lag 10  lag 11  lag 12
# 0     NaN     NaN     NaN
# 1     NaN     NaN     NaN
# 2     NaN     NaN     NaN
# 3     NaN     NaN     NaN
# 4     NaN     NaN     NaN

# %% [markdown]
# ## Number of Lags

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']
X = pd.DataFrame()

lag_counts = range(0, 20)
scores = []

for i in lag_counts:
    X['lag {}'.format(i)] = y.shift(i)
    model, score = fit_model(t, X, y, distance=12)
    scores.append(score)
    
plt.figure()
plt.plot(lag_counts, scores, lw=2)
plt.xlabel('# of Lags')
plt.ylabel('Test Score')
# Out:
#     lag 0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12  112.0 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0
# 12 -1.366857
# 13 -1.295165
# 14 -1.127884
# 15 -1.163730
# 16 -1.259319
#     lag 0  lag 1
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# 6     NaN    NaN
# 7     NaN    NaN
# 8     NaN    NaN
# 9     NaN    NaN
# 10    NaN    NaN
# 11    NaN    NaN
# 12  112.0    NaN 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1
# 13 -1.314158 -1.389927
# 14 -1.146145 -1.315505
# 15 -1.182148 -1.141854
# 16 -1.278155 -1.179065
# 17 -1.110143 -1.278294
#     lag 0  lag 1  lag 2
# 0     NaN    NaN    NaN
# 1     NaN    NaN    NaN
# 2     NaN    NaN    NaN
# 3     NaN    NaN    NaN
# 4     NaN    NaN    NaN
# 5     NaN    NaN    NaN
# 6     NaN    NaN    NaN
# 7     NaN    NaN    NaN
# 8     NaN    NaN    NaN
# 9     NaN    NaN    NaN
# 10    NaN    NaN    NaN
# 11    NaN    NaN    NaN
# 12  112.0    NaN    NaN 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2
# 14 -1.163321 -1.335433 -1.418086
# 15 -1.199458 -1.160959 -1.340522
# 16 -1.295820 -1.198346 -1.159538
# 17 -1.127185 -1.298045 -1.198320
# 18 -0.970596 -1.123572 -1.301740
#     lag 0  lag 1  lag 2  lag 3
# 0     NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3
# 15 -1.213202 -1.178912 -1.361599 -1.434458
# 16 -1.309742 -1.216450 -1.179675 -1.354554
# 17 -1.140797 -1.316551 -1.218658 -1.168110
# 18 -0.983920 -1.141374 -1.322615 -1.208062
# 19 -0.983920 -0.978710 -1.140691 -1.314601
#     lag 0  lag 1  lag 2  lag 3  lag 4
# 0     NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN    NaN 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3     lag 4
# 16 -1.325135 -1.230751 -1.198584 -1.376414 -1.433028
# 17 -1.155773 -1.331057 -1.237741 -1.188947 -1.352188
# 18 -0.998508 -1.155522 -1.342158 -1.229118 -1.163561
# 19 -0.998508 -0.992525 -1.159427 -1.336243 -1.203981
# 20 -1.143676 -0.992525 -0.989749 -1.148775 -1.311768
#     lag 0  lag 1  lag 2  lag 3  lag 4  lag 5
# 0     NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN    NaN    NaN 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3     lag 4     lag 5
# 17 -1.173801 -1.347137 -1.252734 -1.208496 -1.374216 -1.430661
# 18 -1.015912 -1.171125 -1.357393 -1.248857 -1.184546 -1.348949
# 19 -1.015912 -1.007686 -1.174240 -1.356484 -1.225190 -1.158286
# 20 -1.161656 -1.007686 -1.004170 -1.168136 -1.333572 -1.199142
# 21 -1.368126 -1.158553 -1.004170 -0.993242 -1.143903 -1.308092
#     lag 0  lag 1  lag 2  lag 3  lag 4  lag 5  lag 6
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN    NaN    NaN    NaN 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3     lag 4     lag 5     lag 
#     lag 0  lag 1  lag 2  lag 3  lag 4  lag 5  lag 6  lag 7  lag 8  lag 9  \
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     lag 10  lag 11  lag 12  lag 13  lag 14  lag 15  lag 16  lag 17  lag 18  \
# 0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 12     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#     lag 19
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN   0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3     lag 4     lag 5     lag 6  \
# 31 -1.005097 -1.003816 -1.295990 -1.626501 -1.451233 -1.336089 -1.525692
# 32 -1.160102 -1.003816 -0.998874 -1.278294 -1.597060 -1.424103 -1.304313
# 33 -1.483027 -1.165902 -0.998874 -0.973613 -1.247076 -1.570794 -1.392865
# 34 -1.728451 -1.503579 -1.168655 -0.973613 -0.940840 -1.218737 -1.540451
# 35 -1.392608 -1.760214 -1.522364 -1.147717 -0.940840 -0.910687 -1.186244
#
#        lag 7     lag 8     lag 9    lag 10    lag 11    lag 12    lag 13  \
# 31 -1.639778 -1.554649 -1.707579 -1.451215 -1.180739 -0.991744 -0.988025
# 32 -1.478999 -1.598290 -1.505830 -1.665246 -1.423437 -1.166064 -0.988025
# 33 -1.259754 -1.438273 -1.549062 -1.465484 -1.637582 -1.413018 -1.169739
# 34 -1.347452 -1.220067 -1.390544 -1.508290 -1.437713 -1.630918 -1.427167
# 35 -1.493615 -1.307350 -1.174384 -1.351334 -1.480542 -1.427544 -1.654310
#
#       lag 14    lag 15    lag 16    lag 17    lag 18    lag 19
# 31 -1.193257 -1.411345 -1.257055 -1.185242 -1.395836 -1.460686
# 32 -0.986361 -1.181591 -1.389767 -1.235573 -1.158408 -1.359208
# 33 -0.986361 -0.968248 -1.157521 -1.369789 -1.209286 -1.122426
# 34 -1.177341 -0.968248 -0.941864 -1.134911 -1.344959 -1.173165
# 35 -1.447898 -1.165180 -0.941864 -0.916811 -1.107531 -1.308469
# Text(0,0.5,'Test Score')

# %% [markdown]
# ## More Types of Features

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']

# create features in new dataframe
X = pd.DataFrame()
X['lag 0'] = y.shift(0)
X['lag 1'] = y.shift(1)
X['lag 2'] = y.shift(2)
X['lag 3'] = y.shift(3)
X['lag 4'] = y.shift(4)
X['lag 5'] = y.shift(5)
X['lag 6'] = y.shift(6)
X['lag 7'] = y.shift(7)
X['lag 8'] = y.shift(8)
X['lag 9'] = y.shift(9)
X['lag 10'] = y.shift(10)
X['lag 11'] = y.shift(11)
X['lag 12'] = y.shift(12)
X['t'] = (t - t.min())/(t.max() - t.min())
X['rolling mean 3'] = y.rolling(3).mean()
X['rolling mean 6'] = y.rolling(6).mean()
X['rolling mean 12'] = y.rolling(12).mean()
X['rolling std 12'] = y.rolling(12).std()
X['rolling min 12'] = y.rolling(12).min()
X['rolling max 12'] = y.rolling(12).max()
X['rolling median 12'] = y.rolling(12).median()

model, score = fit_model(t, X, y, plot=True, distance=12)

feature_importance_summary(model)
# Out:
#     lag 0  lag 1  lag 2  lag 3  lag 4  lag 5  lag 6  lag 7  lag 8  lag 9  \
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12  112.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#           ...          lag 11  lag 12    t  rolling mean 3  rolling mean 6  \
# 0         ...             NaN     NaN  NaN             NaN             NaN
# 1         ...             NaN     NaN  NaN             NaN             NaN
# 2         ...             NaN     NaN  NaN             NaN             NaN
# 3         ...             NaN     NaN  NaN             NaN             NaN
# 4         ...             NaN     NaN  NaN             NaN             NaN
# 5         ...             NaN     NaN  NaN             NaN             NaN
# 6         ...             NaN     NaN  NaN             NaN             NaN
# 7         ...             NaN     NaN  NaN             NaN             NaN
# 8         ...             NaN     NaN  NaN             NaN             NaN
# 9         ...             NaN     NaN  NaN             NaN             NaN
# 10        ...             NaN     NaN  NaN             NaN             NaN
# 11        ...             NaN     NaN  NaN             NaN             NaN
# 12        ...             NaN     NaN  0.0             NaN             NaN
#
#     rolling mean 12  rolling std 12  rolling min 12  rolling max 12  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# 5               NaN             NaN             NaN             NaN
# 6               NaN             NaN             NaN             NaN
# 7               NaN             NaN             NaN             NaN
# 8               NaN             NaN             NaN             NaN
# 9               NaN             NaN             NaN             NaN
# 10              NaN             NaN             NaN             NaN
# 11              NaN             NaN             NaN             NaN
# 12              NaN             NaN             NaN             NaN
#
#     rolling median 12
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
#
# [13 rows x 21 columns] 0     112
# 1     118
# 2     132
# 3     129
# 4     121
# 5     135
# 6     148
# 7     148
# 8     136
# 9     119
# 10    104
# 11    118
# 12    115
# Name: y, dtype: int64
#        lag 0     lag 1     lag 2     lag 3     lag 4     lag 5     lag 6  \
# 24 -1.552292 -1.518227 -1.706675 -1.498677 -1.243483 -1.057963 -1.040065
# 25 -1.415034 -1.556955 -1.519547 -1.704179 -1.478335 -1.225369 -1.040065
# 26 -1.227864 -1.414954 -1.559646 -1.512377 -1.685557 -1.462528 -1.209696
# 27 -1.302732 -1.221317 -1.412616 -1.553477 -1.492149 -1.671785 -1.450007
# 28 -1.427512 -1.298772 -1.212122 -1.402776 -1.533594 -1.476478 -1.662046
#
#        lag 7     lag 8     lag 9        ...            lag 11    lag 12  \
# 24 -1.197160 -1.364675 -1.224950        ...         -1.324016 -1.387910
# 25 -1.013572 -1.167025 -1.337928        ...         -1.127209 -1.302539
# 26 -1.013572 -0.983493 -1.140216        ...         -1.169382 -1.103338
# 27 -1.183038 -0.983493 -0.956627        ...         -1.281843 -1.146024
# 28 -1.423114 -1.152907 -0.956627        ...         -1.085036 -1.259853
#
#            t  rolling mean 3  rolling mean 6  rolling mean 12  rolling std 12  \
# 24 -1.702857       -1.634106       -1.529884        -1.461963       -1.402954
# 25 -1.664716       -1.536863       -1.582071        -1.451907       -1.426550
# 26 -1.630267       -1.435200       -1.570210        -1.440595       -1.383736
# 27 -1.592127       -1.346797       -1.532256        -1.433053       -1.372592
# 28 -1.555217       -1.351217       -1.482441        -1.428025       -1.385650
#
#     rolling min 12  rolling max 12  rolling median 12
# 24       -1.396934       -1.449862          -1.494438
# 25       -1.396934       -1.449862          -1.455835
# 26       -1.396934       -1.449862          -1.455835
# 27       -1.396934       -1.449862          -1.409511
# 28       -1.396934       -1.449862          -1.409511
#
# [5 rows x 21 columns]
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# <style  type="text/css" >
#     #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.1%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.1%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.1%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.8%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.8%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.3%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.4%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 0%);
#         }    #T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow16_col0 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Importance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row0" class="row_heading level0 row0" >lag 0</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow0_col0" class="data row0 col0" >45.918</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row1" class="row_heading level0 row1" >t</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow1_col0" class="data row1 col0" >28.0498</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row2" class="row_heading level0 row2" >lag 12</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow2_col0" class="data row2 col0" >23.0298</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row3" class="row_heading level0 row3" >rolling min 12</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow3_col0" class="data row3 col0" >16.1501</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row4" class="row_heading level0 row4" >lag 11</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow4_col0" class="data row4 col0" >7.70923</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row5" class="row_heading level0 row5" >rolling mean 3</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow5_col0" class="data row5 col0" >5.10292</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row6" class="row_heading level0 row6" >lag 2</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow6_col0" class="data row6 col0" >4.84383</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row7" class="row_heading level0 row7" >lag 1</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow7_col0" class="data row7 col0" >4.30631</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row8" class="row_heading level0 row8" >rolling max 12</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow8_col0" class="data row8 col0" >4.28897</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row9" class="row_heading level0 row9" >lag 7</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow9_col0" class="data row9 col0" >4.28684</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row10" class="row_heading level0 row10" >lag 9</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow10_col0" class="data row10 col0" >3.94522</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row11" class="row_heading level0 row11" >lag 8</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow11_col0" class="data row11 col0" >3.60473</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row12" class="row_heading level0 row12" >lag 4</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow12_col0" class="data row12 col0" >3.39727</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row13" class="row_heading level0 row13" >lag 10</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow13_col0" class="data row13 col0" >2.89323</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row14" class="row_heading level0 row14" >rolling std 12</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow14_col0" class="data row14 col0" >2.50131</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row15" class="row_heading level0 row15" >lag 6</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow15_col0" class="data row15 col0" >1.42604</td>
#     </tr>    <tr>
#         <th id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8flevel0_row16" class="row_heading level0 row16" >rolling median 12</th>
#         <td id="T_3a99e3fe_de30_11e8_a624_acbc32b0ef8frow16_col0" class="data row16 col0" >0.0162185</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# # Time Learning Curve

# %%
row_counts = range(X.shape[0] // 2, X.shape[0] + 1)
scores = []

for n in row_counts:
    recent = X.index[-n:]
    model, score = fit_model(t.loc[recent], X.loc[recent, :], y.loc[recent], distance=12)
    scores.append(score)

plt.figure()
plt.plot(100.0*np.array(row_counts)/X.shape[0], scores, lw=2)
plt.axhline(max(scores), linestyle='--', color='gray')
plt.xlabel('% recent rows')
plt.ylabel('Test Score')

plt.figure(figsize=(9,3))
plt.plot(t, y, '-', lw=2)
plt.axvline(t.iloc[-np.argmax(row_counts)], linestyle='--', color='gray')
# Out:
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# ## Forecast Distance

# %%
distances = range(0, 36)
scores = []

for i in distances:
    model, score = fit_model(t, X, y, distance=i)
    scores.append(score)

plt.figure()
plt.plot(distances, scores, lw=2)
plt.xlabel('Forecast Distance')
plt.ylabel('Test Score')
# Out:
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Text(0,0.5,'Test Score')

# %% [markdown]
# ## Log Transform / Differencing

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']

# normal
plt.figure(figsize=(9,3))
plt.plot(t, y)
plt.ylabel('Normal')

# differencing
plt.figure(figsize=(9,3))
plt.plot(t, y - y.shift(12), 'r')
plt.ylabel('12 Month Differenced')

# log transform
log_y = y.apply(np.log)
plt.figure(figsize=(9,3))
plt.plot(t, log_y, 'g');
plt.ylabel('Log Transformed')

# both
plt.figure(figsize=(9,3))
plt.plot(t, log_y - log_y.shift(12), 'm')
plt.ylabel('Differenced and Log Transformed')
# Out:
# Text(0,0.5,'Differenced and Log Transformed')
